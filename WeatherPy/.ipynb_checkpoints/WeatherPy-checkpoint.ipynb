# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

base_url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}appid={weather_api_key}&units={units}&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | blackmans bay
# Processing Record 3 of Set 1 | puerto natales
# Processing Record 4 of Set 1 | port douglas
# Processing Record 5 of Set 1 | utrik
# Processing Record 6 of Set 1 | stanley
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | heroica caborca
# Processing Record 10 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | medina
# Processing Record 15 of Set 1 | menongue
# Processing Record 16 of Set 1 | acarau
# Processing Record 17 of Set 1 | kashmar
# Processing Record 18 of Set 1 | hawaiian paradise park
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | grytviken
# Processing Record 21 of Set 1 | camapua
# Processing Record 22 of Set 1 | college
# Processing Record 23 of Set 1 | hami
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | shimokizukuri
# Processing Record 26 of Set 1 | adamstown
# Processing Record 27 of Set 1 | lihue
# Processing Record 28 of Set 1 | farafangana
# Processing Record 29 of Set 1 | porkhov
# Processing Record 30 of Set 1 | olonkinbyen
# Processing Record 31 of Set 1 | el amria
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | waitangi
# Processing Record 34 of Set 1 | edinburgh of the seven seas
# Processing Record 35 of Set 1 | klyuchi
# Processing Record 36 of Set 1 | nishinoomote
# Processing Record 37 of Set 1 | kapa'a
# Processing Record 38 of Set 1 | olinda
# Processing Record 39 of Set 1 | west island
# Processing Record 40 of Set 1 | isafjordur
# Processing Record 41 of Set 1 | zaozersk
# Processing Record 42 of Set 1 | miles city
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | okhotsk
# Processing Record 45 of Set 1 | holualoa
# Processing Record 46 of Set 1 | fortaleza
# Processing Record 47 of Set 1 | chonchi
# Processing Record 48 of Set 1 | atchison
# Processing Record 49 of Set 1 | weno
# Processing Record 50 of Set 1 | badger
# Processing Record 0 of Set 2 | flying fish cove
# Processing Record 1 of Set 2 | hamilton
# Processing Record 2 of Set 2 | udachny
# Processing Record 3 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 4 of Set 2 | eirunepe
# Processing Record 5 of Set 2 | pizarro
# Processing Record 6 of Set 2 | margaret river
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | qaqortoq
# Processing Record 9 of Set 2 | redwood falls
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | papatowai
# Processing Record 12 of Set 2 | port mathurin
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | bilibino
# Processing Record 15 of Set 2 | esquel
# Processing Record 16 of Set 2 | sao felix do xingu
# Processing Record 17 of Set 2 | rabo de peixe
# Processing Record 18 of Set 2 | kogalym
# Processing Record 19 of Set 2 | portage la prairie
# Processing Record 20 of Set 2 | st. john's
# Processing Record 21 of Set 2 | yulinshi
# Processing Record 22 of Set 2 | watford city
# Processing Record 23 of Set 2 | mermoz boabab
# Processing Record 24 of Set 2 | alotau
# City not found. Skipping...
# Processing Record
# Processing Record 1 of Set 4 | gevrai
# Processing Record 2 of Set 4 | souillac
# Processing Record 3 of Set 4 | verkhnevilyuysk
# Processing Record 4 of Set 4 | haiku-pauwela
# Processing Record 5 of Set 4 | al bayda'
# Processing Record 6 of Set 4 | kharan
# Processing Record 7 of Set 4 | zeya
# Processing Record 8 of Set 4 | coronel suarez
# Processing Record 9 of Set 4 | emporia
# Processing Record 10 of Set 4 | fort bragg
# Processing Record 11 of Set 4 | chake chake
# Processing Record 12 of Set 4 | pangoa
# Processing Record 13 of Set 4 | pesaro
# Processing Record 14 of Set 4 | uturoa
# Processing Record 15 of Set 4 | enewetak
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | puerto lleras
# Processing Record 18 of Set 4 | ust'-barguzin
# Processing Record 19 of Set 4 | nemuro
# Processing Record 20 of Set 4 | kievka
# Processing Record 21 of Set 4 | coruripe
# Processing Record 22 of Set 4 | saint-benoit
# Processing Record 23 of Set 4 | marshall
# Processing Record 24 of Set 4 | muriti
# Processing Record 25 of Set 4 | pariaman
# Processing Record 26 of Set 4 | vilyuchinsk
# Processing Record 27 of Set 4 | kingscliff
# Processing Record 28 of Set 4 | ilulissat
# Processing Record 29 of Set 4 | alindao
# Processing Record 30 of Set 4 | quellon
# Processing Record 31 of Set 4 | malacacheta
# Processing Record 32 of Set 4 | zhanga buqtyrma
# Processing Record 33 of Set 4 | palora
# Processing Record 34 of Set 4 | prienai
# Processing Record 35 of Set 4 | sanming
# Processing Record 36 of Set 4 | aras-asan
# Processing Record 37 of Set 4 | dubbo
# Processing Record 38 of Set 4 | kapuskasing
# Processing Record 39 of Set 4 | pisco
# Processing Record 40 of Set 4 | cat ba
# City not found. Skipping...
# Processing Record 41 of Set 4 | cockburn town
# Processing Record 42 of Set 4 | liuhe
# Processing Record 43 of Set 4 | anchorage
# Processing Record 44 of Set 4 | selfoss
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | kuraymah
# Processing Record 47 of Set 4 | nar'yan-mar
# Processing Record 48 of Set 4 | falam
# Processing Record 49 of Set 4 | villa gesell
# Processing Record 0 of Set 5 | humaita
# Processing Record 1 of Set 5 | hithadhoo
# Processing Record 2 of Set 5 | two rivers
# Processing Record 3 of Set 5 | rongelap
# Processing Record 4 of Set 5 | khandyga
# Processing Record 5 of Set 5 | port macquarie
# Processing Record 6 of Set 5 | plaquemine
# Processing Record 7 of Set 5 | polyarnyy
# Processing Record 8 of Set 5 | polohy
# Processing Record 9 of Set 5 | zaragoza
# Processing Record 10 of Set 5 | bel ombre
# Processing Record 11 of Set 5 | invercargill
# Processing Record 12 of Set 5 | kingston
# Processing Record 13 of Set 5 | arraial do cabo
# Processing Record 14 of Set 5 | deir ez-zor
# Processing Record 15 of Set 5 | nova sintra
# Processing Record 16 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 17 of Set 5 | sarayonu
# Processing Record 18 of Set 5 | bardai
# Processing Record 19 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 20 of Set 5 | walvis bay
# Processing Record 21 of Set 5 | la ronge
# Processing Record 22 of Set 5 | koya
# Processing Record 23 of Set 5 | al ghayzah
# Processing Record 24 of Set 5 | barra
# Processing Record 25 of Set 5 | keflavik
# Processing Record 26 of Set 5 | coquimbo
# Processing Record 27 of Set 5 | wynyard
# Processing Record 28 of Set 5 | tevragh zeina
# City not found. Skipping...
# Processing Record 29 of Set 5 | burabay
# Processing Record 30 of Set 5 | yardimli
# Processing Record 31 of Set 5 | xai-xai
# Processing Record 32 of Set 5 | whitehorse
# Processing Record 33 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 34 of Set 5 | susner
# Processing Record 35 of Set 5 | lompoc
# Processing Record 36 of Set 5 | tura
# Processing Record 37 of Set 5 | jacmel
# Processing Record 38 of Set 5 | antonio enes
# Processing Record 39 of Set 5 | kristiansund
# Processing Record 40 of Set 5 | bonthe
# Processing Record 41 of Set 5 | mabaruma
# Processing Record 42 of Set 5 | cape coast
# Processing Record 43 of Set 5 | north platte
# Processing Record 44 of Set 5 | susuman
# Processing Record 45 of Set 5 | straldzha
# Processing Record 46 of Set 5 | umea
# Processing Record 47 of Set 5 | tucuma
# Processing Record 48 of Set 5 | korla
# Processing Record 49 of Set 5 | tiksi
# Processing Record 0 of Set 6 | general jose de san martin
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | radashkovichy
# Processing Record 3 of Set 6 | carboneras
# Processing Record 4 of Set 6 | hoxtolgay
# City not found. Skipping...
# Processing Record 5 of Set 6 | palu
# Processing Record 6 of Set 6 | kalininsk
# Processing Record 7 of Set 6 | slave lake
# Processing Record 8 of Set 6 | karymskoye
# Processing Record 9 of Set 6 | morondava
# Processing Record 10 of Set 6 | saint croix
# Processing Record 11 of Set 6 | barra de santo antonio
# Processing Record 12 of Set 6 | bontang
# Processing Record 13 of Set 6 | taoudenni
# Processing Record 14 of Set 6 | priob'ye
# Processing Record 15 of Set 6 | portland
# Processing Record 16 of Set 6 | lethem
# Processing Record 17 of Set 6 | sodra sandby
# Processing Record 18 of Set 6 | codrington
# Processing Record 19 of Set 6 | san antonio de pale
# Processing Record 20 of Set 6 | birjand
# Processing Record 21 of Set 6 | lichtenburg
# Processing Record 22 of Set 6 | wailua homesteads
# Processing Record 23 of Set 6 | luanda
# Processing Record 24 of Set 6 | chinsali
# Processing Record 25 of Set 6 | mahina
# Processing Record 26 of Set 6 | notodden
# Processing Record 27 of Set 6 | punta arenas
# Processing Record 28 of Set 6 | aykhal
# Processing Record 29 of Set 6 | masterton
# Processing Record 30 of Set 6 | tolanaro
# Processing Record 31 of Set 6 | la plata
# Processing Record 32 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 33 of Set 6 | al kharijah
# Processing Record 34 of Set 6 | awjilah
# Processing Record 35 of Set 6 | sinabang
# Processing Record 36 of Set 6 | mina clavero
# Processing Record 37 of Set 6 | douentza
# Processing Record 38 of Set 6 | poronaysk
# Processing Record 39 of Set 6 | kalabo
# Processing Record 40 of Set 6 | awka
# Processing Record 41 of Set 6 | avarua
# Processing Record 42 of Set 6 | isangel
# Processing Record 43 of Set 6 | hermanus
# Processing Record 44 of Set 6 | borovskoy
# Processing Record 45 of Set 6 | tucurui
# Processing Record 46 of Set 6 | afaahiti
# Processing Record 47 of Set 6 | ustka
# Processing Record 48 of Set 6 | south grafton
# Processing Record 49 of Set 6 | manado
# Processing Record 0 of Set 7 | puerto deseado
# Processing Record 1 of Set 7 | sao vicente
# Processing Record 2 of Set 7 | tulum
# Processing Record 3 of Set 7 | coyhaique
# Processing Record 4 of Set 7 | jiangkou
# Processing Record 5 of Set 7 | whitecourt
# Processing Record 6 of Set 7 | mayen abun
# City not found. Skipping...
# Processing Record 7 of Set 7 | zuenoula
# Processing Record 8 of Set 7 | itarantim
# Processing Record 9 of Set 7 | muynoq
# Processing Record 10 of Set 7 | pula
# Processing Record 11 of Set 7 | crane
# Processing Record 12 of Set 7 | kirakira
# Processing Record 13 of Set 7 | kourou
# Processing Record 14 of Set 7 | aquin
# Processing Record 15 of Set 7 | wainwright
# Processing Record 16 of Set 7 | bilgoraj
# Processing Record 17 of Set 7 | anadyr
# Processing Record 18 of Set 7 | mahibadhoo
# Processing Record 19 of Set 7 | richards bay
# Processing Record 20 of Set 7 | santona
# Processing Record 21 of Set 7 | cromer
# Processing Record 22 of Set 7 | kyren
# Processing Record 23 of Set 7 | carandai
# Processing Record 24 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 25 of Set 7 | nuku'alofa
# Processing Record 26 of Set 7 | chinde
# Processing Record 27 of Set 7 | makueni boma
# Processing Record 28 of Set 7 | guerrero negro
# Processing Record 29 of Set 7 | kodiak
# Processing Record 30 of Set 7 | misratah
# Processing Record 31 of Set 7 | cimitarra
# Processing Record 32 of Set 7 | la passe
# Processing Record 33 of Set 7 | troitsko-pechorsk
# Processing Record 34 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 35 of Set 7 | havre
# Processing Record 36 of Set 7 | llaillay
# Processing Record 37 of Set 7 | haverhill
# Processing Record 38 of Set 7 | acapulco de juarez
# Processing Record 39 of Set 7 | puerto armuelles
# Processing Record 40 of Set 7 | boundiali
# Processing Record 41 of Set 7 | nyurba
# Processing Record 42 of Set 7 | gangtok
# Processing Record 43 of Set 7 | san martin
# Processing Record 44 of Set 7 | pailitas
# Processing Record 45 of Set 7 | tacna
# Processing Record 46 of Set 7 | praia
# Processing Record 47 of Set 7 | guozhen
# Processing Record 48 of Set 7 | kruisfontein
# Processing Record 49 of Set 7 | karratha
# Processing Record 0 of Set 8 | lorengau
# Processing Record 1 of Set 8 | conduaga
# Processing Record 2 of Set 8 | estevan
# Processing Record 3 of Set 8 | hilo
# Processing Record 4 of Set 8 | kuppam
# Processing Record 5 of Set 8 | kailua-kona
# Processing Record 6 of Set 8 | anna regina
# Processing Record 7 of Set 8 | campo grande
# Processing Record 8 of Set 8 | minas de marcona
# Processing Record 9 of Set 8 | homa bay
# Processing Record 10 of Set 8 | sur
# Processing Record 11 of Set 8 | constantia
# Processing Record 12 of Set 8 | tvoroyri
# Processing Record 13 of Set 8 | castro
# Processing Record 14 of Set 8 | kuta
# Processing Record 15 of Set 8 | velasco ibarra
# Processing Record 16 of Set 8 | al wajh
# Processing Record 39 of Set 9 | lisakovsk
# Processing Record 40 of Set 9 | livny
# Processing Record 41 of Set 9 | nazyvayevsk
# Processing Record 42 of Set 9 | thunder bay
# Processing Record 43 of Set 9 | cabo san lucas
# Processing Record 44 of Set 9 | ciudad bolivar
# Processing Record 45 of Set 9 | edeia
# Processing Record 46 of Set 9 | huanan
# Processing Record 47 of Set 9 | toungo
# Processing Record 48 of Set 9 | mejit
# Processing Record 49 of Set 9 | al jawf
# Processing Record 0 of Set 10 | kyaiklat
# Processing Record 1 of Set 10 | christchurch
# Processing Record 2 of Set 10 | pudozh
# Processing Record 3 of Set 10 | kalemie
# Processing Record 4 of Set 10 | pacasmayo
# Processing Record 5 of Set 10 | wad rawah
# Processing Record 6 of Set 10 | mount pearl
# Processing Record 7 of Set 10 | tralee
# Processing Record 8 of Set 10 | touros
# Processing Record 9 of Set 10 | gadzhiyevo
# Processing Record 10 of Set 10 | takoradi
# Processing Record 11 of Set 10 | berezovyy
# Processing Record 12 of Set 10 | akureyri
# Processing Record 13 of Set 10 | houghton
# Processing Record 14 of Set 10 | nelson bay
# Processing Record 15 of Set 10 | enriquillo
# Processing Record 16 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 17 of Set 10 | roma
# Processing Record 18 of Set 10 | likiep
# Processing Record 19 of Set 10 | saudarkrokur
# Processing Record 20 of Set 10 | nantucket
# Processing Record 21 of Set 10 | nyamti
# Processing Record 22 of Set 10 | shubarshi
# Processing Record 23 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 24 of Set 10 | mitu
# Processing Record 25 of Set 10 | sambava
# Processing Record 26 of Set 10 | dolinsk
# Processing Record 27 of Set 10 | grootfontein
# Processing Record 28 of Set 10 | lucas
# Processing Record 29 of Set 10 | sharjah
# Processing Record 30 of Set 10 | freetown
# Processing Record 31 of Set 10 | natchez
# Processing Record 32 of Set 10 | mamou
# Processing Record 33 of Set 10 | al muwayh
# Processing Record 34 of Set 10 | okahao
# Processing Record 35 of Set 10 | el calafate
# Processing Record 36 of Set 10 | elko
# Processing Record 37 of Set 10 | kenora
# Processing Record 38 of Set 10 | newport
# Processing Record 39 of Set 10 | kilindoni
# Processing Record 40 of Set 10 | happy valley-goose bay
# Processing Record 41 of Set 10 | smithers
# Processing Record 42 of Set 10 | cold lake
# Processing Record 43 of Set 10 | sao joao da barra
# Processing Record 44 of Set 10 | el haouaria
# Processing Record 45 of Set 10 | bakchar
# Processing Record 46 of Set 10 | general conesa
# Processing Record 47 of Set 10 | chiras
# Processing Record 48 of Set 10 | lagoa
# Processing Record 49 of Set 10 | manavalakurichi
# Processing Record 0 of Set 11 | sinjai
# Processing Record 1 of Set 11 | bikaner
# Processing Record 2 of Set 11 | broken hill
# Processing Record 3 of Set 11 | chiroqchi
# Processing Record 4 of Set 11 | kenai
# Processing Record 5 of Set 11 | la gi
# Processing Record 6 of Set 11 | save
# Processing Record 7 of Set 11 | llallagua
# Processing Record 8 of Set 11 | kiunga
# Processing Record 9 of Set 11 | al jaradiyah
# Processing Record 10 of Set 11 | shetpe
# Processing Record 11 of Set 11 | minas de matahambre
# City not found. Skipping...
# Processing Record 12 of Set 11 | tromso
# Processing Record 13 of Set 11 | homer
# Processing Record 14 of Set 11 | pio xii
# Processing Record 15 of Set 11 | casa santa
# City not found. Skipping...
# Processing Record 16 of Set 11 | port blair
# Processing Record 17 of Set 11 | ginir
# Processing Record 18 of Set 11 | lazaro cardenas
# Processing Record 19 of Set 11 | fortuna
# Processing Record 20 of Set 11 | woolgoolga
# Processing Record 21 of Set 11 | northwood
# Processing Record 22 of Set 11 | arno
# Processing Record 23 of Set 11 | gaozhou
# Processing Record 24 of Set 11 | kone
# Processing Record 25 of Set 11 | ouricuri
# Processing Record 26 of Set 11 | ustrzyki dolne
# Processing Record 27 of Set 11 | karachi
# Processing Record 28 of Set 11 | el naranjo
# Processing Record 29 of Set 11 | cooper's town
# Processing Record 30 of Set 11 | lata
# Processing Record 31 of Set 11 | tyukhtet
# Processing Record 32 of Set 11 | las lomitas
# Processing Record 33 of Set 11 | tqvarch'eli
# Processing Record 34 of Set 11 | lively
# Processing Record 35 of Set 11 | lyantor
# Processing Record 36 of Set 11 | egilsstadir
# Processing Record 37 of Set 11 | lampang
# Processing Record 38 of Set 11 | arkhangel'sk
# Processing Record 39 of Set 11 | ambo
# Processing Record 40 of Set 11 | pakala
# Processing Record 41 of Set 11 | imperial
# Processing Record 42 of Set 11 | motueka
# Processing Record 43 of Set 11 | nago
# Processing Record 44 of Set 11 | viedma
# Processing Record 45 of Set 11 | jawhar
# Processing Record 46 of Set 11 | yashan
# Processing Record 47 of Set 11 | aspen
# Processing Record 48 of Set 11 | shillong
# Processing Record 49 of Set 11 | swan hill
# Processing Record 0 of Set 12 | at taj
# Processing Record 1 of Set 12 | boa viagem
# Processing Record 2 of Set 12 | vetovo
# Processing Record 3 of Set 12 | huarmey
# Processing Record 4 of Set 12 | bushehr
# Processing Record 5 of Set 12 | fallon
# Processing Record 6 of Set 12 | oppdal
# Processing Record 7 of Set 12 | vila franca do campo
# Processing Record 8 of Set 12 | yaren
# Processing Record 9 of Set 12 | cozumel
# Processing Record 10 of Set 12 | kapshagay
# Processing Record 11 of Set 12 | naberera
# Processing Record 12 of Set 12 | las navas del marques
# Processing Record 13 of Set 12 | umm as sahik
# Processing Record 14 of Set 12 | tofol
# Processing Record 15 of Set 12 | elverum
# Processing Record 16 of Set 12 | paungde
# Processing Record 17 of Set 12 | kabare
# Processing Record 18 of Set 12 | dubti
# Processing Record 19 of Set 12 | beaufort west
# Processing Record 20 of Set 12 | andergrove
# Processing Record 21 of Set 12 | igarka
# Processing Record 22 of Set 12 | ar raqqah
# Processing Record 23 of Set 12 | trincomalee
# Processing Record 24 of Set 12 | scalea
# Processing Record 25 of Set 12 | behshahr
# Processing Record 26 of Set 12 | inhambane
# Processing Record 27 of Set 12 | zaraza
# Processing Record 28 of Set 12 | lapaha
# City not found. Skipping...
# Processing Record 29 of Set 12 | tabou
# Processing Record 30 of Set 12 | kil'mez'
# City not found. Skipping...
# Processing Record 31 of Set 12 | outokumpu
# Processing Record 32 of Set 12 | qaisumah
# Processing Record 33 of Set 12 | praia da vitoria
# Processing Record 34 of Set 12 | dubovka
# Processing Record 35 of Set 12 | dongyang
# Processing Record 36 of Set 12 | harper
# Processing Record 37 of Set 12 | tanout
# Processing Record 38 of Set 12 | aljezur
# Processing Record 39 of Set 12 | port saint john's
# Processing Record 40 of Set 12 | luderitz
# Processing Record 41 of Set 12 | tsiombe
# Processing Record 42 of Set 12 | roses
# Processing Record 43 of Set 12 | rikaze
# Processing Record 44 of Set 12 | sao lourenco do sul
# Processing Record 45 of Set 12 | krumovgrad
# Processing Record 46 of Set 12 | jamaame
# Processing Record 47 of Set 12 | shizunai-furukawacho
# Processing Record 48 of Set 12 | tot'ma
# Processing Record 49 of Set 12 | colceag
# Processing Record 0 of Set 13 | westport
# Processing Record 1 of Set 13 | beykonak
# Processing Record 2 of Set 13 | shalqar
# Processing Record 3 of Set 13 | basco
# Processing Record 4 of Set 13 | sept-iles
# Processing Record 5 of Set 13 | puerto baquerizo moreno
# Processing Record 6 of Set 13 | nicoya
# Processing Record 7 of Set 13 | shannon
# Processing Record 8 of Set 13 | penzance
# Processing Record 9 of Set 13 | kirensk
# Processing Record 10 of Set 13 | lerwick
# Processing Record 11 of Set 13 | bodo
# Processing Record 12 of Set 13 | yanykurgan
# Processing Record 13 of Set 13 | sampit
# Processing Record 14 of Set 13 | kahama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          590
# Lat           590
# Lng           590
# Max Temp      590
# Humidity      590
# Cloudiness    590
# Wind Speed    590
# Country       590
# Date          590
# dtype: int64

# %%
# Display sample data
len(city_data_df)
# Out:
# 590

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             jamestown  42.0970  -79.2353     15.01        91         100
# 1         blackmans bay -43.0167  147.3167     10.29        87          78
# 2        puerto natales -51.7236  -72.4875     10.25        53           0
# 3          port douglas -16.4833  145.4667     24.86        85         100
# 4                 utrik  11.2278  169.8474     26.68        80          99
#
#          Wind Speed Country        Date
# City_ID
# 0              3.60      US  1712770682
# 1              3.88      AU  1712770971
# 2              7.72      CL  1712770944
# 3              3.24      AU  1712770971
# 4             10.40      MH  1712770866

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors = 'black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.title("City Latitude vs Max Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors = 'black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors = 'black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors = 'black')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Wind Speed (m/s)")
plt.title("City Latitude vs Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
from scipy.stats import linregress
def linear_regression(df, x_axis, y_axis): 
    
    #obtain x and y values from the dataframe
    x_values = df[x_axis]
    y_values = df[y_axis]

    #Perform Linear Regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    #line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    line_eq = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}'
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    #annotate the equation on the graph. The 'xycoords' portion sourced from ChatGPT
    plt.annotate(line_eq, (0.1, 0.9), xycoords='axes fraction', fontsize=15, color="red") 
    plt.title(("{} vs. {}").format(y_axis, x_axis))
    plt.xlabel(x_axis)
    plt.ylabel(y_axis)
    print(f"The r-value is: {rvalue}")
    print(f"The equation of the regression line is: {line_eq}")

    # Save the figure
    #plt.savefig("figures/ScatterWeightTumorVolRegression.png")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"]>=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              jamestown  42.0970  -79.2353     15.01        91         100
# 4                  utrik  11.2278  169.8474     26.68        80          99
# 5                stanley  54.8680   -1.6985     12.01        90          40
# 6             georgetown   5.4112  100.3354     28.30        86          20
# 8        heroica caborca  30.7167 -112.1500     25.62        14           0
#
#          Wind Speed Country        Date
# City_ID
# 0              3.60      US  1712770682
# 4             10.40      MH  1712770866
# 5              6.69      GB  1712770972
# 6              1.54      MY  1712770946
# 8              0.72      MX  1712770680

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df["Lat"]<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            blackmans bay -43.0167  147.3167     10.29        87          78
# 2           puerto natales -51.7236  -72.4875     10.25        53           0
# 3             port douglas -16.4833  145.4667     24.86        85         100
# 7                  ushuaia -54.8000  -68.3000      8.79        66          40
# 10       port-aux-francais -49.3500   70.2167      7.75        99         100
#
#          Wind Speed Country        Date
# City_ID
# 1              3.88      AU  1712770971
# 2              7.72      CL  1712770944
# 3              3.24      AU  1712770971
# 7             13.38      AR  1712770972
# 10             5.55      TF  1712770836

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df,"Lat","Max Temp")
plt.show()
# Out:
# The r-value is: -0.8521375806981466
# The equation of the regression line is: y = -0.58x + 36.8

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df,"Lat","Max Temp")
plt.show()
# Out:
# The r-value is: 0.769037991203645
# The equation of the regression line is: y = 0.36x + 29.76

# %% [markdown]
# **Discussion about the linear relationship:** for cities in the northern hemisphere, there is an inverse relationship between max temp and latitude; as the latitude increases with movement away from the equator, there is a clear drop in maximum temperature. The maximum temperature at 0 degrees latitude is 36.8 degrees C, which is the Y intecept as seen in the equation (y = -.58x +36.8). For cities in the southern hemisphere, there is a positive relationship between max temp and latitude; as the latitude decreases with movement away from the equator, there is a clear drop in maximum temperature. Based on the equation (y = 0.36x + 29.76, a max temperature of 0 would occur at a latitude of -82.67, which is the South Pole)

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df,"Lat","Humidity")
plt.show()
# Out:
# The r-value is: 0.3138722409991985
# The equation of the regression line is: y = 0.39x + 51.47

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df,"Lat","Humidity")
plt.show()
# Out:
# The r-value is: 0.2556181127272937
# The equation of the regression line is: y = 0.3x + 80.12

# %% [markdown]
# **Discussion about the linear relationship:** There is a positive relationship between latitude and humidity in the southern hemisphere. As the latitudes increase towards the equator (0 deg), the humidity increases. The humidity at zero degress latitude would be around 80.12.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df,"Lat","Cloudiness")
plt.show()
# Out:
# The r-value is: 0.1297618776579093
# The equation of the regression line is: y = 0.26x + 46.86

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df,"Lat","Cloudiness")
plt.show()
# Out:
# The r-value is: 0.22405618440363165
# The equation of the regression line is: y = 0.56x + 72.53

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df,"Lat","Wind Speed")
plt.show()
# Out:
# The r-value is: 0.04925549022134384
# The equation of the regression line is: y = 0.01x + 3.86

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df,"Lat","Wind Speed")
plt.show()
# Out:
# The r-value is: -0.40140468586115396
# The equation of the regression line is: y = -0.07x + 2.42

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
